# %% [markdown]
# Question 1: What is Deep Learning? Briefly describe how it evolved and how it differs from traditional machine learning.
#
# Answer: Deep Learning is a part of Machine Learning which is based on the artificaial neural network it work similar to human brain learn new patterns from the data by using multi layer neural network these layers help to learn complex patterns from the data like images, text, sound. Machine learning models was very simple and depended on the manual feature extraction and selection but in deep learning we don’t need to extract features manually from the dataset.
# Difference between Deep Learning and Machine Learning
# ●	Machine learning need manual feature extraction
# ●	Deep learning learn feature automitacally
# ●	Deep learning work better on large dataset
# ●	Machine learning model are simpler and fast to train
# ●	Deep learning need more data and computation power
#
# Question 2: Explain the basic architecture and functioning of a Perceptron. What are its limitations?
#
# Answer: A perceptron is the simplest neural network model it contains input values weights a bias and an activation function working  each input is multiplied by its weight all the values are added together along with the bias
# This total value is passed through an activation function to get the output
# Limitations:
# ●	It can solve only simple linear problems
# ●	It gives only binary output
# ●	It does not have hidden layers
# Question 3: Describe the purpose of activation function in neural networks. Compare Sigmoid, ReLU, and Tanh functions.
# Answer: Activation functions are used to add non linearity to neural networks without activation functions the neural network will behave like a linear model and cannot solve complex problems
#
#
# Comparison:
# Activation Function	Range	Advantages	Disadvantages
# Sigmoid	0 to 1	Simple, used for binary output	Slow training, vanishing gradient
# Tanh	-1 to 1	Zero centered	Vanishing gradient
# Relu	0 to infinity	Fast and simple	Dying ReLU problem
#
# Question 4: What is the difference between Loss function and Cost function in neural networks? Provide examples.
# Answer: Loss function calculates the error for one training example while cost function calculates the average loss for the entire dataset
# Examples:
# ●	Loss Function: Mean Squared Error, Binary Cross Entropy
# ●	Cost Function: Average of loss values for all samples
# Question 5: What is the role of optimizers in neural networks? Compare Gradient Descent, Adam, and RMSprop.
# Answer: Optimizers are used to update the weights of the neural network in such a way that the loss is minimized
# Optimizer - Gradient Descent, RMSprop, Adam
# Description - Simple but slow, Adjusts learning rate automatically, Fast and commonly used.
#
# Question 9: Visualize loss and accuracy curves and explain.
# Answer: import matplotlib.pyplot as plt
#
#      plt.plot(history.history['loss'], label='Loss')
#      plt.plot(history.history['accuracy'], label='Accuracy')
#      plt.legend()
#      plt.show()
# loss decreases and accuracy increases, which means the model is learning properly
#
# Question 10: Fraud Detection – Real-Time Workflow
# Answer: For fraud detection, I will use a multilayer neural network.
# ●	ReLU activation for hidden layers and Sigmoid for output layer
# ●	Binary Cross Entropy loss function
# ●	Handle imbalance using class weights
# ●	Evaluate using precision and recall
# ●	Use Adam optimizer
# ●	Prevent overfitting using dropout and early stopping

# %%
#Question 6: Write a Python program to implement a single-layer perceptron for AND gate.
import numpy as np
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,0,0,1])
weights = np.zeros(2)
bias = 0
lr = 0.1
for epoch in range(10):
  for i in range(len(X)):
    y_pred = 1 if np.dot(X[i], weights) + bias >= 0 else 0
    error = y[i] - y_pred
    weights += lr * error * X[i]
    bias += lr * error
print("Weights:", weights)
print("Bias:", bias)
# Out:
# Weights: [0.2 0.1]
# Bias: -0.20000000000000004

# %%
#Question 7: Implement and visualize Sigmoid, ReLU, and Tanh activation functions.
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
sigmoid = 1 / (1 + np.exp(-x))
relu = np.maximum(0, x)
tanh = np.tanh(x)

plt.plot(x, sigmoid, label='Sigmoid')
plt.plot(x, relu, label='ReLU')
plt.plot(x, tanh, label='Tanh')
plt.legend()
plt.show()

# %%
#Question 8: Build and train a neural network on MNIST dataset using Keras.
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

(X_train, y_train), _ = mnist.load_data()
X_train = X_train / 255.0
y_train = to_categorical(y_train)

model = Sequential([
     Flatten(input_shape=(28,28)),
     Dense(128, activation='relu'),
               Dense(10, activation='softmax')])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=5)
print("Training Accuracy:", history.history['accuracy'][-1])
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8800 - loss: 0.4221
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9649 - loss: 0.1213
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9776 - loss: 0.0762
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9847 - loss: 0.0552
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9873 - loss: 0.0429
# Training Accuracy: 0.986050009727478
